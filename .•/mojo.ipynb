# %%
from utils.numerics import *

fn main():
# Out:
# error: Expression [4] wrapper:8:3: could not find an 'Error' type
#   try:
#   ^
# error: Expression [4] wrapper:13:76: could not find an 'Error' type
# def __mojo_repl_expr_impl__(mut __mojo_repl_arg: __mojo_repl_context__) -> None:
#                                                                            ^
# error: Expression [4] wrapper:11:5: use of unknown declaration 'print'
#     print("Error:", error)
#     ^~~~~
# error: Expression [4] wrapper:14:33: could not find an 'Bool' type
#   var __mojo_repl_expr_failed = True
#                                 ^
# error: Expression [4] wrapper:16:36: could not find an 'Error' type
#   def __mojo_repl_expr_body__() -> None:
#                                    ^
# error: Expression [4] wrapper:16:7: could not find an 'object' type
#   def __mojo_repl_expr_body__() -> None:
#       ^
# error: Expression [4] wrapper:19:29: could not find an 'Bool' type
#   __mojo_repl_expr_failed = False
#                             ^
# ...
